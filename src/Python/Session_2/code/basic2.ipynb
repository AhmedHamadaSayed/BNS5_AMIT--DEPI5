# %%
list_one = [1,2,3,4,"deep learning" , "Machine learning", "true",[1,2,3,["dl","ml","llm"]]]
print(list_one)
print(type(list_one))
# Out:
# [1, 2, 3, 4, 'deep learning', 'Machine learning', 'true', [1, 2, 3, ['dl', 'ml', 'llm']]]
# <class 'list'>

# %%
list_one[7][3][1] = "lll"
list_one
# Out:
# [1,
#  2,
#  3,
#  4,
#  'deep learning',
#  'Machine learning',
#  'true',
#  [1, 2, 3, ['dl', 'lll', 'llm']]]

# %%
Ahmed =list ("Amit")
print(Ahmed)
# Out:
# ['A', 'm', 'i', 't']

# %%
list_one = [1,2,3,4,"deep learning" , "Machine learning", "true",[1,2,3,["dl","ml","llm"]]]

print(list_one.append(1))
# Out:
# None

# %%
list_one
# Out:
# [1,
#  2,
#  3,
#  4,
#  'deep learning',
#  'Machine learning',
#  'true',
#  [1, 2, 3, ['dl', 'ml', 'llm']],
#  1]

# %%
list_1 = ["Depi","ml","dl"]
list_2 = [1,2,3]
list_1.append("geni")
print(list_1)
# Out:
# ['Depi', 'ml', 'dl', 'geni']

# %%
list_1.append(list_2)
print(list_1)
# Out:
# ['Depi', 'ml', 'dl', 'geni', [1, 2, 3]]

# %%
list_1.extend(list_2)
print(list_1)
# Out:
# ['Depi', 'ml', 'dl', 'geni', [1, 2, 3], 1, 2, 3]

# %%
list_1.extend("cv")
print(list_1)
# Out:
# ['Depi', 'ml', 'dl', 'geni', [1, 2, 3], 1, 2, 3, 'c', 'v', 'c', 'v']

# %%
list_1.insert(0,"NLP")
print(list_1)
# Out:
# ['NLP', 'NLP', 'Depi', 'ml', 'dl', 'geni', [1, 2, 3], 1, 2, 3, 'c', 'v', 'c', 'v']

# %%
list_1.remove("NLP")
print(list_1)
# Out:
# ['NLP', 'Depi', 'ml', 'dl', 'geni', [1, 2, 3], 1, 2, 3, 'c', 'v', 'c', 'v']

# %%
list_3 = ["DEPI","Amit","AI"]
x = list_3.pop()
list_3
# Out:
# ['DEPI', 'Amit']

# %%
list_4 = ["CV","NLP"]
list_4.append(x)
list_4
# Out:
# ['CV', 'NLP', 'AI']

# %%
del list_4[]
list_4
# Out:
#   Cell In[65], line 1
#     del list_4[]
#                ^
# SyntaxError: invalid syntax

# %%
name = input("enter your Nme")
print(name)
# Out:
# Ahmed

# %%
name = input("enter your Nme")
print(type(name))
# Out:
# <class 'str'>

# %%
name = input("enter your Nme")
Age = input("Enter your Age")
print(f"my name is:{name} - and my age is:{Age}")
# Out:
# my name is:Ahmed - and my age is:22

# %%
assignmentlist = ["amit","python","machine learining","data science","machine learning"]
item = input("Enter Your Remove")
assignmentlist.remove(item)
print(assignmentlist)
# Out:
# ['python', 'machine learining', 'data science', 'machine learning']

# %%
my_list = [1,2,7,5,9,8]
my_list.sort()
print(my_list)
# Out:
# [1, 2, 5, 7, 8, 9]

# %%
my_list = [1,2,7,5,9,8]
my_list.reverse()
print(my_list)
# Out:
# [8, 9, 5, 7, 2, 1]

# %%
my_list = [1,2,7,5,9,8]
my_list.sort(reverse=True)
print(my_list)
# Out:
# [9, 8, 7, 5, 2, 1]
