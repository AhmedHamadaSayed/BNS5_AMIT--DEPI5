# %%
lst_1= [10,2,30,4]
x = lst_1.sort()
print(x)
print(lst_1)
# Out:
# None
# [2, 4, 10, 30]

# %%
x= sorted(lst_1)
# Out:
# [2, 4, 10, 30]

# %%
def fuc_1(*name):
    print(name)
    print(type(name))

# %%
fuc_1("hello", "depi", 222,2.9, "true")
# Out:
# ('hello', 'depi', 222, 2.9, 'true')
# <class 'tuple'>

# %%
print("my name is Ahmed and my age 22".format("name", "age"))
# Out:
# my name is Ahmed and my age 22

# %%
def func_2(**name):
    print(name)
    print(type(name))

# %%
func_2(name="Ahmeed", age=22 , city="cairo")
# Out:
# {'name': 'Ahmeed', 'age': 22, 'city': 'cairo'}
# <class 'dict'>

# %%
fun_11 = lambda x: x+10
type(fun_11)
# Out:
# function

# %%
for i in range(10):
    lambda i : i*100

# %%
xy = lambda x,y : x+y
print(xy(10,20))
# Out:
# 30

# %%
def fuc_33(n):
    return lambda a: a*n

# %%
x= fuc_33(2)
print(x(11))
# Out:
# 22

# %%
num = 5
result = 1
for i in range(1, num +1):
    result *=i
print(result)
# Out:
# 120

# %%
def factorial(num):
    '''  
    Calculate n! using recursion.
 
Parameters
----------
num : int
 
Returns
-------
    '''
    if num <0:
        raise valueError("factorial is undefined for negative valuess")
        
    if num == 0 or num == i:
        return 1
        
    return num * factorial(num - 1)

# %%
for i in range (2,10):
    is num % i ==0:
        print ("False")
    print("true")
# Out:
#   Cell In[43], line 2
#     is num % i ==0:
#     ^
# SyntaxError: invalid syntax

# %%
def is_prime(num):
    """
Check whether a number is prime.
 
Parameters
----------
num : int
Number to test.
 
Returns
-------
bool
True if prime, otherwise False.
"""

    for i in range (2, num):
        if num % i ==0:
            return False
        return true

# %%
is_prime(10)   #type hints
# Out:
# False

# %%
def common_divisors(num1: int, num2: int) -> list[int]:
    limit = min(num1 , num2)
    divisors = []
    
    for divisor in range(1, limit+1):
        if num % divisor == 0 and num2 % divisor ==0:
            divisor.append(divisor)
    return divisors

# %%
common_divisors(20,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 common_divisors(20,10)
#
# Cell In[55], line 7, in common_divisors(num1, num2)
#       3     divisors = []
#       4
#       5     for divisor in range(1, limit+1):
#       6         if num % divisor == 0 and num2 % divisor ==0:
# ----> 7             divisor.append(divisor)
#       8     return divisors
#
# AttributeError: 'int' object has no attribute 'append'

# %%
s = "welcome Depi"
lst = s.split(" ")
print(lst)
new_list = lst [::-1]
print(new_list)
# Out:
# ['welcome', 'Depi']
# ['Depi', 'welcome']

# %%
def reverse_string(text: str) -> list:
    """"
    return the reverse string into inversed list
    
    """
    return text[::-1]

# %%
reverse_string("welcome depi")
# Out:
# 'iped emoclew'

# %%
def str_to_lst(word: str) -> list[str]:
    """
    Transform sentence of word to list of words.

    Parameters
    ----------
    word : str
        sentence of word.

    Returns
    -------
    list of String
        list contains the words of sentance.
    """

    lst = word.split()
    return lst


print(str_to_lst("Ahmed Hamada"))
# Out:
# ['Ahmed', 'Hamada']

# %%
str_to_lst("Ahmed Hamada")
# Out:
# ['Ahmed', 'Hamada']

# %%
import random 
char = "string.ascii_letters"
password = ""
pass_lenght = 8

for _ in range(pass_lenght):
    password += random.choice(char)
print(password)
# Out:
# _neterst

# %%
import secrets
import string

def gen_secure_pass(length: int = 12) -> str:
    if length <= 0:
        raise ValueError("Password length must be more than zero")

    char = (
        string.ascii_letters +
        string.digits +
        string.punctuation
    )

    return "".join(secrets.choice(char) for _ in range(length))

# %%
gen_secure_pass()
# Out:
# 'b|+2(>![56{^'

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]

unique_words = set(words)

counts = {word: 0 for word in unique_words}

print(counts)
# Out:
# {'Hi': 0, 'Welcome': 0, 'Ali': 0, 'No': 0}

# %%
for i in unique_words:
    for j in words:
        if i == j:
            counts[i] += 1

counts
# Out:
# {'Hi': 2, 'Welcome': 1, 'Ali': 4, 'No': 3}

# %%
import random
 
# Predefined responses
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}

# %%
# Function to get a response based on user input
def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
   
    return random.choice(responses["default"])
